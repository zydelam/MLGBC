# %% [markdown]
# # Import libraries

# %%
import tensorflow as tf
import string
import re
import pandas as pd
import spacy
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Load data

# %%
df_train = pd.read_csv ("hm_train.csv")
df_train.head()
# Out:
#     hmid reflection_period                                         cleaned_hm  \
# 0  27673               24h  I went on a successful date with someone I fel...
# 1  27674               24h  I was happy when my son got 90% marks in his e...
# 2  27675               24h       I went to the gym this morning and did yoga.
# 3  27676               24h  We had a serious talk with some friends of our...
# 4  27677               24h  I went with grandchildren to butterfly display...
#
#    num_sentence predicted_category
# 0             1          affection
# 1             1          affection
# 2             1           exercise
# 3             2            bonding
# 4             1          affection

# %%
df_test = pd.read_csv("hm_test.csv")
df_test.head()
# Out:
#     hmid reflection_period                                         cleaned_hm  \
# 0  88305                3m    I spent the weekend in Chicago with my friends.
# 1  88306                3m  We moved back into our house after a remodel. ...
# 2  88307                3m  My fiance proposed to me in front of my family...
# 3  88308                3m  I ate lobster at a fancy restaurant with some ...
# 4  88309                3m  I went out to a nice restaurant on a date with...
#
#    num_sentence
# 0             1
# 1             2
# 2             1
# 3             1
# 4             5

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### 1.Cleaning

# %%
def clean(data):
    datarm=[]
    for i in data['cleaned_hm']:
        punct = re.sub(r'\W', ' ', i)
        non_num= re.sub ('[0-9]', '', punct)
        newlines = str(non_num).replace("\n","")
        returns = str(newlines).replace("\r","")
        quotes = str(returns).replace("'","")
        datarm.append(quotes)
    return datarm

# %% [markdown]
# ### 2.Lemmatization

# %%
def lemmatize(data):
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

    data_lemma = []
    for i in data:
        text = nlp(i)
        data_lemma.append([token.lemma_.lower().strip() for token in text])
    data_lemma =[' '.join(i) for i in data_lemma]
    return data_lemma

# %% [markdown]
# ### 3.Stopwords

# %%
def remove_stopwords(data):
    stop_words = nltk.corpus.stopwords.words('english')
    stop_words.append('I')
    temp=[]
    for i in data:
        tokens=word_tokenize(i)
        stopped = [i for i in tokens if i not in stop_words]
        stopped = [''.join(i) for i in stopped]
        temp.append(stopped)
    temp =[' '.join(i) for i in temp]
    return temp

# %% [markdown]
# ### Final preprocess function

# %%
def preprocess_data(data):
    cleaned=clean(data)
    data_cleaned=remove_stopwords(cleaned)
    lemmatized=lemmatize(data_cleaned)
    return lemmatized

# %%
X_train=preprocess_data(df_train)
X_train
# Out:
# ['go successful date someone feel sympathy connection',
#  'happy son get mark examination',
#  'go gym morning yoga',
#  'we serious talk friend flaky lately they understand good evening hang',
#  'go grandchild butterfly display crohn conservatory',
#  'meditate last night',
#  'make new recipe peasant bread come spectacular',
#  'get gift eld brother really surprising',
#  'yesterday my moms birthday so enjoyed',
#  'watch cupcake war three teen child',
#  'come rd place call duty video game',
#  'complete mile run without break it make feel strong',
#  'go movie friend fun',
#  'short gold make trade',
#  'hear song it nearly impossible go angry happy look thought ease angry feel move direction happiness it may take long head positive direction youall world good',
#  'my son perform well test preparation',
#  'help neighbour fix car damage',
#  'manage get final trophy game play',
#  'a hot kiss girl friend last night make day',
#  'my new bcaa come mail yay strawberry lemonade flavor aminos make heart happy',
#  'got a class',
#  'my sister call abroad morning long year such happy occassion family member',
#  'the cake make today come amazing it taste amazing well',
#  'there two type people world choose happy choose unhappy contrary popular belief happiness come fame fortune people material possession',
#  'my grandmother start walk bed long time',
#  'able hit top spin serve tennis',
#  'nap husband bed afternoon sweet cuddle close',
#  'my co woker start play carley rae jepsen song phone ring customer',
#  'my son wake fantastic breakfast egg special hamburger patty pancake',
#  'after long time brother give suprise visit house yesterday',
#  'go movie sister today first time since long time',
#  'consume well garnished bowl raman twice today it delicious',
#  'pick daughter airport fun good conversation way home',
#  'my daughter wave say mama first time come home morning',
#  'go mountain hike trail top',
#  'we compete another team online game play friend childhood friend grow together go school since kid we play game together almost year kinda form team game the game start smoothly everyone hype fight slowly thing start become interesting exciting know become close fight score point winner declare everyone look since know well within friend particular game start command expect enemy this game it team base game vs my team start fail demoralization ensue try well know maneuver attack enemy skill luck dodged counter',
#  'go run neighborhood enjoy perfect weather',
#  'hang fiancee dinner together',
#  'the offsite colleague great fun we stimulate discussion',
#  'my old daughter keep pat young daughter head',
#  'feel lonely long day work when call husband say way pick meeting surprise excited',
#  'receive award work tough loan process help develop',
#  'receive flower good friend',
#  'my spouse give kiss big hug morning go office',
#  'my son give big hug morning',
#  'cook eat wonderful sausage cheese omelet',
#  'achieve daily income goal',
#  'meet favorite superstar first time',
#  'remember yesterday totally different many monday it feel like spring finally sun bright temperature warm',
#  'eat good dinner family',
#  'go shop',
#  'the phone order local online store deliver morning like phone much',
#  'today morning my son s exam result come he have get distinction that be first grade in all subjects feel very happy',
#  'buy new tv',
#  'our national cricket team test match series morning this win seal position test team world this make happy today',
#  'make bunch extra sale side business last night',
#  'walk work back partner',
#  'get promotion today year service job',
#  'my sister long chat happen life right enjoy reconnecte',
#  'wake early morning daily',
#  'partner buy big cake nice tasty never expect cake partner really love lot cake delicious cold taste different compare cake day go interesting spend time partner go movie fun really miss partner day love spend',
#  'log account turk see pending hit get approve still acceptance',
#  'slow cook chuck roast stove come great',
#  'see two close friend see couple month',
#  'cook girlfriend wonderful breakfast',
#  'today morning select junior engineer lead familiar mobile sale company',
#  'smile son face make happy everyday today also get',
#  'happy one day trade give good profit today',
#  'take dog long walk beautiful day',
#  'run around kid husband grab tell beautiful perfect smart special love',
#  'my yrs son feel bad kicking say mom sorry kicking will not repeat feel happy age realize mistake',
#  'long ago man go sea woman wait stand edge water scan horizon tiny ship now wait henry he vanish unwillingly without warn wait each moment wait feel like year eternity my husband comedy man moment happy mood my baby bear moment',
#  'lose kgs weight month long effort put achieve',
#  'finally learn cook chicken',
#  'my girlfriend tell love hope marry one day',
#  'tired work still manage go mile bicycle ride this great since knee surgery month ago',
#  'take girlfriend nice birthday dinner get watch open present it really fun evening',
#  'go run exercise three day break',
#  'income taxis year nice refund come',
#  'everyone work pace compare other if think well someone else gain unhealthy sense superiority if think someone else well end feel bad youall happy focus progress praise other',
#  'able push up today highest do',
#  'my mother give surprise visit home',
#  'we celebrate anniversary boyfriend',
#  'we book beach vacation may year',
#  'after long time wait finally get ticket favourite movie release yesterday first day first show it really awesome feeling still could feel way get goosebump relive moment theatre',
#  'meet city mayor give valuable advice development city',
#  'india won the series against australia make i to feel happy',
#  'finish paint granddaughter bedroom',
#  'after take gym due illness able wake early complete normal squat workout weight do prior break',
#  'last night sister bear baby get new relation uncle happy moment',
#  'get new phone great never phone',
#  'my son result today get good score school happy see result',
#  'get travel visa tourist month australia',
#  'hi the thing make happy finished task office get appreciation team leader work do yesterday moment make happy past hour yesterday perform well first time get team topper position moment make happy',
#  'could suryanamaskars min would otherwise take min',
#  'we know sleep help body recover day repair help we focus productive it turn ita also important happiness our commute office surprisingly powerful impact happiness',
#  'go sport club run exercise feel fresh happy',
#  'get engage parent support',
#  'find poet really love lot twitter',
#  'there hardly traffic way work morning',
#  'get happy task mechanical turk get reward point it make feel happy last hour',
#  'see friend able catch filled joy',
#  'come office right time',
#  'my family go wildlife park it beautiful',
#  'the day get degree industrial engineering',
#  'frankly constipate past day able defecate today bowel get clear moment really make feel happy bowel feel well moment make feel happy really',
#  'read great book motivation attitude',
#  'cricket match play really well',
#  'one happy moment happen past hour would go back work today first time year',
#  'wake early morning witness beautiful sunrise',
#  'take nice warm shower it really good relax',
#  'go vacation native place parent sibling great feel family eat lot family fun',
#  'see rainbow make feel happy since never see rainbow reality',
#  'saw dad go office he popular among staff many people know this thing make happy dad',
#  'yesterday night go movie family we great fun spending time together',
#  'go office hour one professor realize care professor mentor ever',
#  'we ladie member family go lunch seven star hotel n much fun lady go together n gossip',
#  'a make quite progress old rusty workbench restore moment with new paint look like new',
#  'when wife come home work share steak dinner together bottle wine',
#  'julia good girl last night lunge try hard ask without get panicky throw result wobble',
#  'son go football match friend come home happy team match see happy feel happy',
#  'in morning year daughter apply ointment severe headache',
#  'get errand do complete',
#  'gather old friend school',
#  'today happy usual eat veggie put plate usually leave leave plate today',
#  'able beat record bench press',
#  'summer holiday begin kid happy',
#  'this second essay two part series journey visit taj mahal read first part whole story a gra uttar pradesh india as soon train agra leave delhi find confused iam lie reserve upper berth though train car bed arenat use almost passenger sit low seat feel ridiculous like iam emperor train car oversee rest passenger meanwhile man pass offer mysterious vegetarian curry industrial sized bucket motion one serve paper plate try pay food wonat accept money this first time iave get anything free india conclude food go kill while iam eat train make stop passenger disembark conductor make announcement canat see trainas tiny low window upper bunk idea ais agra ask man sit ask nicely possible attempt avoid appear self righteous train car emperor shout question serfs after remember taj mahal builder mughal emperor shah jahan overthrow son soon taj mahalas completion the man shake head hindi think tell still long ride agra another man walk sell non vegetarian food foil tin the first shot intestinal war already fire result free bucket food decline as train chug toward agra stopping station along way find continuously recruit new serfs keep track by time iam halfway journey eighteen year old kid two indian soldier young woman none speak english try assist itas easy accidentally aggregate helper train mercifully indians tend especially protective clueless westerners try make sense indian public transportation at one point two indian soldier demand teenager move foot rest berth young woman make food recommendation bucket whisk theyare kind like four train fairy godmother soon fall asleep suddenly awake sound four indians chant aagra agra unison abruptly end time train car emperor jump bed thank four catch taxi agra guesthouse before leave arrange taxi driver pick am next morning take taj mahal in morning tell driver take east gate taj mahal he promptly take roundabout near west gate instead though aeast gate announcement upon arrival quite convincing indiaas perpetually dishonest taxi driver always ulterior sometimes mysterious motive case try save gas take gate close hotel accord lonely planet possibly collect kickback camel rickshaw driver sit near west gate wait take tourist tajas ticket office donat bother argue since thereas much time sunrise walk quickly entrance standing line twenty mostly indian tourist iam surprise see lack westerner imagine every white person india would flock taj mahal finally door open catch first glimpse building consider beautiful world one whose creator boast make athe sun moon shed tear eye see famous white marble dome peek arch great gate tourist hold camera high head get first snapshot walk deliberately toward around taj soaking dawn slowly take photo every possible angle a handful photographer gather front adjacent taj mahal mosque capture sun rise behind everyone reverent take care interfere othersa photograph offer help take pose picture the moment perfect photographer gaggle mist blanket yamuna river behind structure building look like rise spontaneously cloud heaven concrete manifestation nirvana the simple presence taj build symbol eternal love emperor jahan memory third wife die childbirth seem encourage even rabid photographer cooperate spend almost two hour tour photograph taj walk around wall admire calligraphy entrance arch gaze minaret touch intricate lattice screen mausoleum interior iam finish take final classic taj mahal reflection pool photograph outside beautiful young blond woman perform playful provocative pose friend camera catch eye soon stre indian man indian family start interrupt ask pose souvenir photo athe indian tourist seem interested white skin blond hair white marble taj mahal say aiam pretty sure lot indian guy leave picture taj she chuckle introduce sophie france quickly weare trade funny story travel india we like immediately we find chat front tajas reflection pool half hour indian man gawk we but sophie realize weare head opposite direction toward amritsar northern india towar ...
#  'my father buy bicycle',
#  'crack interview ibm make feel happy like never',
#  'fly one rc model plane around yard able maneuver around tree yard power line side road sometimes minor crash due confine space often able fly nice long flight without incident this one time it super fun',
#  'go home give ice cream family pack family particularly hands son create joyful moment',
#  'my son come home say study word want bond work together',
#  'go grocery store buy cook whole chicken deli find half price day',
#  'my went movie friend popcorn coke be fun',
#  'my neice nephew give hug kiss today morning',
#  'laugh english class silliness last period',
#  'today get drive license wheeler wheeler since last week wait drive license',
#  'complete flashcard upcoming test',
#  'its little thing go gym today squat leg lift power cage open afternoon',
#  'my daughter good big test school',
#  'able sleep long usual',
#  'yesterday solve big issue related family',
#  'in past hour talk friend call often',
#  'long talk son live far away fro we always good conversation',
#  'finally master make crispy tofu',
#  'after long week deep snow cover ground finally enough warm day northeast snow melt able start day fantastic hike appalachian trail run nearby home feel though entire life suddenly come back balance hold back week due enormous amount snowfall',
#  'work principal apply post ceo today morning receive confirm notification mail happy whatever expect give everything post thank remember incident',
#  'get bonus work creative idea come enhance safety buy something nice',
#  'my husband say love u woke morning',
#  'run run run run finally catch bus disappear form eye its make feel nice',
#  'leave key motor cycle search half hour my neighbor house uncle come give key happy',
#  'able get xbox game',
#  'see girl love much mui ne bay that face love miss much',
#  'ride home sunny cool afternoon along riverside path',
#  'get promote senior manager yesterday happy',
#  'meet college friend today we good time together enough time chat we go favourite destination cream centre explore delicious taste ice cream',
#  'take time play pet rabbit',
#  'my husband tell love morning',
#  'my old dog suffer congestive heart failure seem feel much well today feel quite relieved',
#  'super good mail day yesterday receive lot item order amazon',
#  'family go watch film',
#  'eat peanut butter m ms watch john oliver they delicious hilarious',
#  'to day morning trained my neighbor child to run cycle enjoyed a lot',
#  'go dinner friend enjoy lot',
#  'able play video game enjoy quite bit make relaxed happy',
#  'run mile feel great',
#  'get pet gift parent',
#  'intimate relation wonderful person love',
#  'my sore throat clear',
#  'get see girlfriend help celebrate birthday',
#  'bring new mobile day morning',
#  'enjoy play soccer brother',
#  'go power walk local mall many walker smile wave',
#  'a happy moment granddaughter give big hug she kind girl give hug lot get hug wonderful',
#  'in past hour make happy mother day card year old son write kindest sweet note surround beautiful drawing',
#  'go long run trail near house',
#  'come home work dog wag tail previously convince hurt yesterday wag',
#  'get engage lover yesterday',
#  'able full hour research topic nag',
#  'play rock band family',
#  'my wife celebrate ten year anniversary today',
#  'happy daughter call across country',
#  'daughter come first sport race feel proud',
#  'well yesterday start early wake mturk task woke find get unexpected bonus be someone hardly scrape disability check small side job do not pay enough cover bill even cent bonus help honestly nice see work help',
#  'month buy new tcl inch lead tv look cool really love',
#  'solve engineering mechanic problem make happy',
#  'go lunch girlfriend family',
#  'take dog walk around local park it almost degree beautiful day',
#  'wake take care daughter she smiley first thing morning it amazing see smile',
#  'happy realize big concern sing drink',
#  'when get train station pull able get seat',
#  'my wife tell despite lose overtime hour happy around',
#  'go support cousin product launch last night happy proud watch shine',
#  'go park son work yesterday',
#  'my turbo kick class full last night',
#  'able successfully assist friend job search set interview',
#  'cook new recipe dinner turn great',
#  'spend time daughter good friend service last night',
#  'we meet buddy drink dinner last night it great able hang watch hockey',
#  'play new game fun get enjoy mechanic',
#  'happy family bring beautiful gift',
#  'my husband pass dot physical worry anymore',
#  'the weather warm gorgeous first time long time love',
#  'great lunch daughter grandchild enjoy time together',
#  'meet old time friend',
#  'when weigh morning find weight thought',
#  'meet childhood friend year',
#  'go to hotel party of my moms birthday',
#  'my child kiss goodnight',
#  'my girlfriend surprise favorite dinner taco',
#  'get come home early boss vacation',
#  'go restaurant family member',
#  'play kitten',
#  'this great way sum feel happiness ita everything feel like ita click ita sync when part equation break start lose handle happy feeling thata ita important always speak true feeling act accord way feel inside',
#  'able resist drink last night',
#  'cook food mother law and like',
#  'have dinner family dad get sick',
#  'a hot chat date partner make feel sexy',
#  'finally trick dog let give bath sweet smell puppy well',
#  'talk old friend',
#  'see parent fill tear receive phone call huge amount happiness word explain',
#  'deal annoying customer work morning that happen blue moon',
#  'not mucha salade perigourdine full goody glass nice red wine your personal ai assistant write well email the happy moment last hour reunite good mate luke take',
#  'finally complete project enthusiastically',
#  'get job interview dream job',
#  'my mother law offer money could buy yogurt afford buy',
#  'my friend come visit work talk minute',
#  'the mobile home park manager call say come morning fix leaky swamp cooler finally',
#  'finally decorate son room birthday',
#  'cook entire breakfast family',
#  'go local gym lift weight cardio the shower afterwards refreshing',
#  'the rain stop beautiful sunlight appear go walk take photograph',
#  'my application adopt cat come',
#  'take dog walk conversation stranger',
#  'travel family go beautiful beach enjoy attraction area entertainer everywhere lot people gather music band party it pleasant experience hope return anytime soon',
#  'my son give big hug morning wake',
#  'my brother get interview job apply likely get hire',
#  'the offsite colleague great fun we stimulate discussion',
#  'my old daughter keep tell want go bathroom',
#  'the weather sultry place ac unit damage rodent the electrician come early today repair thank god need sweat today',
#  'celebrate th wedding anniversary wife',
#  'meet weight loss goal bet easy',
#  'go walk morning',
#  'my wife wear favorite saree office meeting',
#  'speak ex wife phone make plan see son thursday',
#  'purchase product want fifty percent retail price',
#  'get promotion',
#  'anything else daughter birthday turn special day make day special',
#  'play tennis friend',
#  'my daughter visit evening',
#  'my wife tell pass qualifying exam job promotion',
#  'in my garden plant a rose plant last month yesterday morning a beautiful and colorful rose flourished it make i happy',
#  'delicious lunch',
#  'my two wheeler run find issue front tyre manage this make happy',
#  'really good carbonara chicken dinner',
#  'clean bathroom tile look nice shiny',
#  'bring new game system today',
#  'make dinner boyfriend compliment feel happy compliment able make happy',
#  'measure weight find pound less early day',
#  'today morning go shopping time see one accident unforgettable small boy cross road time one man ride cycle fast kick boy cycle unfortunately boy fall get wound leg hand shout lot cry go close boy take hospital return safe home',
#  'receive call new client ready pay usual simple design',
#  'double daily goal mturk reward short amount time',
#  'smoke bowl marijuana',
#  'able eat dinner one good friend',
#  'in appointment order give surprised salary double get',
#  'yesterday son want ride bike move get happy',
#  'while buy medicine regular pharmacy store come know unused point old purchase pay anything medicine buy',
#  'find tool look long time',
#  'my daughter say donald duck first time say daisy',
#  'so happy have yummy mango year today',
#  'always think night song or moment song to feel much know to eye eagle slope mountain to wave understand influence moon to tree read memory leave to insignificant pedestrian street of crazy city watch watch watch',
#  'my kid get promote next class',
#  'complete long time pende project',
#  'receive enough funding start research project abroad summer',
#  'play competitive game online able get top score among friend also play usually get somewhere top score',
#  'finally go run work feel great take care body',
#  'have nice conversation wife neighbour rarely speak she seem nice',
#  'speak college friend angie minute first time since last summer',
#  'our home extension within wall abode shape mood affect productivity influence outlook life scientific study show impact happiness adjust tiny little habit routine constitute daily life fact control outlook life',
#  'a lot favorite show update recently able watch today',
#  'able leave early office amazing evening mother wife',
#  'eat really good chinese food',
#  'pay bill money usual left transfer saving',
#  'after long debate finally convince parent buy new laptop today as promise also buy new one happy satisfied',
#  'when get back home wife make good food like',
#  'friend gift i a ring for my paper select for national conference',
#  'take shower wife',
#  'able go grocery store save money buy impulse item alcohol try stay away',
#  'today early morning boss call surprised boss say you get promotion salary increase',
#  'take walk girlfriend night',
#  'we go movie telugu movie favourite hero new movie release awesome movie',
#  'my daughter get reward good english speech class',
#  'the next thing make happy get one special offer telecom service reduce package plan moment make happy',
#  'could finally eat favourite restaurant long time',
#  'recently become friend really great group people yesterday order pizza chinese taco bell then sit around talk eat good time talk sister law eat chocolate custard spend time young child',
#  'yesterday evening friend play badminton enjoy',
#  'get surprise gift parent',
#  'my husband purchase thing like market',
#  'when get home work girlfriend greet hug dinner already prepare setup table',
#  'meet childhood friend long time get hug moment wonderful',
#  'able celebrate father birthday treat dinner to able see happy truly make happy',
#  'ride bike speed km per hour',
#  'clean kitchen feel great',
#  'find new job',
#  'order product amazon get deliver today moment make feel happy',
#  'story advice get read',
#  'puzzle game website require fast reflex',
#  'another happy moment happen past hour one year old daughter take step morning',
#  'when wake young daughter morning school insist would make breakfast consist coffee toast',
#  'read comic_strip book whilst drink cocoa drink',
#  'the offsite colleague great fun enjoy perfect weather enjoy watch sunset porch',
#  'complete work target boss appreciate good work moment feel happiness',
#  'eat sugar candy party long it remind childhood',
#  'today get bonus amount dollar requester mturk',
#  'go get sushi high school friend like small reunion',
#  'early morning get many message n wish friend n family member new year today feel love everyone',
#  'joke around mum get home work make happy turn make happy well',
#  'when wife share pleasure both we happy',
#  'watch field full horse work mad happy hon get stunning recall little dogleg',
#  'return home work help old couple reach destination bless we make happy',
#  'receive call letter university job',
#  'spend time parent',
#  'online game get new event give many diamond',
#  'work back bicep',
#  'get finish tv serie watch mom',
#  'get offer pizza nearby hotel happy',
#  'sunset time sun go night begin during sunset nature assume fresh bright charming the sun seem disc gold at time sunset one enjoy serenity sunset then nature seem hurry people finish work return home bird return nest the cowboy become busy return home cattle when sun set nature look beautiful then nature start get dark the slight darkness sunset create feel joy tranquility we the beauty sunset help poet generate idea compose poem',
#  'celebrate birthday friend',
#  'got respect friend social welfare thing',
#  'get early daylight go outside fly one rc quadcopter equip led light while light make easy see orient quadcopter still somewhat difficult see tree obstruction yard able fly minute around yard home neighbor yard permission fly total darkness challenge super fun',
#  'give aadhar card update poor man minimum cost moment feel happy',
#  'find new community move pond kayak launch',
#  'the extra memory purchase computer arrive today easy install',
#  'my husband buy favourite sweet really make happy',
#  'finally get driver license',
#  'we really good rehearsal friday night play',
#  'today afternoon p husband suddenly plan vacation tour he book ticket whole trip expect husband',
#  'make tasty chocolate pudding every one enjoy',
#  'it payday everyday payday happy day able finally pay last remain balance birth twin',
#  'my husband make favorite food dinner',
#  'level game',
#  'happy solve major issue',
#  'watch series movie',
#  'one last azalea bloom come today happy see flower kill late frost week back',
#  'get offer help photographer friend shoot cubs season opener game',
#  'able find time go hair cut something put month look great',
#  'meet old friend study year back link unexpectedly meet airport it surprise later remember childhood day present life',
#  'get computer fix finally now get back thing need get do',
#  'participate ugadi food festival office',
#  'do job plan please',
#  'write mba assignment send study center courier after see paper insert at phoned courier office tell send cover go keep paper time really happy',
#  'get new iphone plus product red',
#  'basketball medal team leader mvp match',
#  'some triathlon gear waiting arrive last pleasing positive resolution seller very pleased purchase fit perform really well',
#  'my friend throw surprise party promotion yesterday happy',
#  'friend go favourite amusement park end street we great time we go amazing ride elated ecstasy',
#  'finally finish new york times crossword work',
#  'my friend call tell possible job opening field',
#  'the mechanic contact repair truck much less expensive anticipate',
#  'able stay calorie yesterday continue fast eat friend weekend',
#  'hole family dinner',
#  'play dog outside it sunny fun',
#  'last night go to hotel for a dinner with y girl friend',
#  'get gift brother without reason',
#  'able go workout coworker mine preppe day make happy',
#  'manage earn dollar one hour work',
#  'day make breakfast parent',
#  'feel baby move belly first time',
#  'get positive comment work',
#  'able run outside complete k new record time nice weather feel like spring',
#  'yesterday receive message get promote manager company',
#  'love watch sunset beach',
#  'go costco daughter buy anything',
#  'when drive home house see beautiful sunset',
#  'sit outside drinking cup tea sunshine surround recently bloom tulip',
#  'eat lunch mom dad',
#  'someone need retire work breathe heavily like lung go quit she lazy worker want leave',
#  'bring dress parent day',
#  'able hit earning goal day think originally high',
#  'get extra sleep last night',
#  'my mother call blue tell proud',
#  'happy lunch husband',
#  'maid cook delicious meal today family',
#  'like say wake early get start mturk yesterday morning daughter stop get coffee morning it nice much need',
#  'month buy new tcl inch lead tv look cool really love',
#  'play cricket friend',
#  'find bag think lose',
#  'watch kid play together fight',
#  'make delicious homemade pad thai husband happy eat give many compliment',
#  'bet morning',
#  'my job provide lunch really good',
#  'run long duration far',
#  'make chappati first time turn amazing',
#  'cook dinner son make meatball',
#  'my year old come sit lap watch tv',
#  'make delicious meal use fresh ingredient without go grocery store',
#  'pass evaluation work fly color',
#  'service look forward attend end great time friend daughter',
#  'really happy find friend mine get marry they even ask wedding',
#  'listen music hear entire album hear',
#  'happy get new incentive hardworke work',
#  'go bible study tonight special need friend',
#  'my fiance find old magic gathering card brother go throw bring home',
#  'make vacation plan daughter today florida july',
#  'eat favorite dinner',
#  'the difficult dog hardly ever listen finally decide come today call',
#  'my mother prepare special biriyani friend',
#  'go to theatre and make happy with my family',
#  'my husband kiss hello',
#  'play tug war new dog leo',
#  'share big breakfast boyfriend',
#  'get bonus work get regularly',
#  'get email old friend',
#  'it may take long youare head positive direction world good go internal system guidance sure way feel less perfectly happy always strive line three aspect happy life',
#  'my mother recover weakness chemotherapy cycle',
#  'bring gift sibling',
#  'watch new episode show like',
#  'a good win sport team',
#  'manage get eight minute mile pace kind awesome',
#  'buy new wallet look',
#  'my car loan clear yesterday happy',
#  'get a test barely study',
#  'you might think would money power fame well think positive psychology guru martin seligman study happiness find characteristic happy people how rate come feel happy',
#  'become leader great squad achieve high rank',
#  'gt a exam',
#  'thinking dream life death reflection make feel complete peace',
#  'get new underwear mail purchase online',
#  'my pen pal vermont call unexpectedly we friend year hope meet person day',
#  'enjoy dinner brother family garden restaurant yesterday',
#  'beat final boss dark souls',
#  'drive around town run errand there much traffic spring break',
#  'my cat sick yesterday eat food scamper around apartment',
#  'my husband get promote job make money',
#  'meet girlfriend park talk',
#  'me family go travel nearby beach see beautiful performance pyro dancer first time encounter talent really impressive say anything performance petrify awe see could move scenario even performance end could help think think time would see performance visit place hopefully come across specific performer',
#  'the offsite colleague great fun we stimulate discussion',
#  'my computer hard drive failure get finally repair',
#  'my son give big hug morning wake',
#  'my young daughter lift head',
#  'struggle relocate wardrobe near windows husband without knowledge back dropping kid school',
#  'work able keep entire tape',
#  'complete office work go nice brunch parter',
#  'enjoy watch soccer',
#  'the offsite colleague great fun we stimulate discussion',
#  'receive message seemingly charming lady plenty fish date app',
#  'find something lose week',
#  'buy new phone',
#  'get see good old friend come daughter birthday',
#  'finish work early usually',
#  'go park',
#  'able reach target weight today kg need lose still happy',
#  'last evening in my office get a gift contain a tour package include my family for the success in my project felt surprise and happy',
#  'go gym',
#  'make tea morning ginger my wife like much make happy',
#  'find great deal samsonite backpack',
#  'talk mother phone half hour',
#  'go co worker celebrate promotion',
#  'pick cat turn arm seem hug back purr happy happy',
#  'buy new t shirt',
#  'eagerly wait see friend engagement function really cute beautiful happy engagement love one friend character really good adjustable partner also kind humble make love long year live together relationship understand well get soon get marry',
#  'go movie without much expectation turn one good movie see',
#  'the rain stop able take long walk dog daybreak',
#  'meet group people see almost half year',
#  'able play favorite game hour',
#  'during lunch time my lovely wife give special hug sweet kiss',
#  'go son school open house yesterday teacher tell positively make happy',
#  'india cricket test match australia today',
#  'great dinner bake chicken hominy bread salad',
#  'my mom take we dinner eat shrimp chimichanga',
#  'go ride enfield bullet morning weather husband its awesome',
#  'during formative year company employ foreign expert improve production its management foresight establish r d department even though product range small',
#  'my long time good friend come visit family many year',
#  'replace television home',
#  'find go start new highly potent new medication ibs believe could finally provide relief',
#  'my former manager extend sick leave due injury come back work yesterday he first manager get current job mentor',
#  'play guitar first time it really satisfy make music',
#  'a good dinner nice restaurant coworker',
#  'take kid school today first day spring break',
#  'one reason experience memory experience make we happy material thing due entire cycle enjoyment experience provide planning experience look forward experience enjoy experience remembering experience make home gallery positive memory',
#  'lunch friend see awhile',
#  'watch favorite movie wife late night',
#  'finally get job interview',
#  'spend time relax husband watch television',
#  'today travel bus meet strange long talk the man meet equal book he amaze many fact experience life he also give many life hack deal many day day problem glad new friend today',
#  'when claim back insurance money insurance company',
#  'get appreciation for my academic performance from my head of the mechanical department',
#  'make love wife',
#  'finally able complete several small task work list awhile always supersede task',
#  'last night father give gift bike special also happy moment',
#  'see dig work',
#  'my cousin come native see son stay london today come home happy see house',
#  'my cousin brother get engage love year',
#  'the third thing make happy get one credit card offer that increase reward point purchase also offer free movie ticket exclusively credit card make happy',
#  'could help rescue one puppy suffer street seeing since one month give inner peace happiness',
#  'fail programming class in last hour start complete basic python very big achievement really happy moment go get bed notice daughter tuck picture draw say bedtime surprise it super sweet make day',
#  'get challenge work boss',
#  'get huge amount gift friend engagement gift',
#  'my son sing song',
#  'my brother call night check',
#  'get offer avail loan bank low interest rate make happy',
#  'complete goal bicep curl gym work couple week able accomplish easily today',
#  'eat favourite food item lunch',
#  'my husband make delicious breakfast',
#  'my good friend birthday',
#  'run business get order normal moment make feel happy',
#  'feel motivation move right direction know',
#  'dinner family we go new restaurant nearby',
#  'one thing make happy past hour would almost three year old son give kiss cheek tell love',
#  'due cooler weather afternoon finally manage prune tree garden',
#  'when get want seat cinema it make watch movie experience whole lot well',
#  'meet old friend year talk half day play football like old day',
#  'usually play game get strike level yesterday complete level make happy',
#  'today make eye contact crush she also look eye for second two still memorize beautiful eye',
#  'it drizzle morning go walk love weather',
#  'take mom small hill lake elsinore fill lot flower',
#  'last night sister get new car go drive new car',
#  'manage one legged squat right leg weak left process level happy progress',
#  'finally get taxis complete feel happiness relief do',
#  'lol vix make giggle mine horse ultra soppy today groom brush good boy one buck today yesterday ride',
#  'little one month old wait first step take first step yesterday see feel happy',
#  'play along daughter friend',
#  'have good nap',
#  'holiday sunday i m happy',
#  'drank ounce glass water',
#  'finish paper college class',
#  'make cake tasty everyone home enjoy',
#  'morning walk good exercise an early riser regular morning walker the benefit morning walk manifold in early morning everything look fresh fair the atmosphere remain pleasant calm a morning walker breathe pollution free air he enjoy lovely sight sound nature all soothe soul regular morning walk keep one fit it help form sound health science say morning walk control blood pressure lessen stress strain energize one work zealously now day live fast life we work round clock we hardly time care health if habit morning walk form right early day sure sound body sound mind besides health benefit extremely delightful experience take walk early morning',
#  'go temple parent',
#  'finally succeed make tomato soup',
#  'take small refractor telescope yard look star planet able view jupiter moon surround planet though would love much large telescope one perform well with short focal length eyepiece view jupiter nice indeed',
#  'give r donation expense temple fund happy',
#  'my daughter tell good cook',
#  'after dinner able enjoy quiet moment porch coffee cigar',
#  'after long time today cousin come home surprisingly make day',
#  'enjoy meditation shaolin temple nearby',
#  'nice conversation good friend work',
#  'go birthday party son friend today talk friend mother openly chat happily nice lunch in party get new friend son enjoy lot',
#  'manage throw item cluttering room enjoy space',
#  'my son great soccer practice really come along learn new skill well really learn control body',
#  'buy brand new dress look beautiful',
#  'get book movie ticket',
#  'elder bless dare powerful gut',
#  'live tweet group fan',
#  'able fit back pair jean able wear year',
#  'it warm enough drive car window open',
#  'a good friend inform dave chappelle stand comedy act release netflix that end evening yesterday huge grin face',
#  'my spouse underwent cancer medical treatment major scan doctor say nothing worry perfectly good take home happy',
#  'get get together people church help retirement home it always good feel help people',
#  'have log walk friend heavy lunch',
#  'when come home year son hug wait',
#  'get r cash gift quiz participate three month it useful correct time feel happy',
#  'see friend see long time',
#  'that day see work coffe house she beautiful',
#  'finish read crime novel john harvey didn think would read rest last night get hook towards end',
#  'finally purchase dream house yesterday feel happy',
#  'friend go favourite restaurant we eat special dish we go astonished taste delicacy',
#  'spend time kitchen make chicken soup',
#  'cook tasty dinner leftover',
#  'call sister wish happy birthday nice telephone chat',
#  'the weather start warm super happy',
#  'enjoy week end family',
#  'color adult coloring book watch netflix it relax enjoyable',
#  'to day morning join a gim',
#  'meet school friend enjoy lot',
#  'able play outside child weather nice make happy',
#  'get wet spring rain',
#  'day go cinema girlfriend',
#  'satisfy many food craving dinner',
#  'meet old friend see',
#  'get ticket see favorite movie play right even though sell currently',
#  'go temple parent',
#  'go run neighborhood enjoy perfect weather',
#  'watch bates motel favorite television show',
#  'when son take eat nice restaurant',
#  'walk first morning light dog sun creep behind rush bird full song',
#  'watch new episode favorite television show',
#  'make delicious meal',
#  'receive lottery amount today',
#  'talk mom phone amazing call',
#  'my cat snuggle leg sleep',
#  'today take day part time job go brunch date wonderful wife',
#  'happy make sale business',
#  'rain today make surrounding beautiful',
#  'finish mturk work bit early since weather nice go work pile firewood yard some small piece good stack toss grill fire right smoke chicken it turn amazing',
#  'month buy new tcl inch lead tv look cool really love',
#  'get approval coffee girl crush',
#  'a bakery give extra pastry end day',
#  'go shop local thrift store find great deal two chair',
#  'we watch always sunny philadelphia show always make laugh happy',
#  'accomplished errand day spare time relax',
#  'start new project work something really interesting seem like fun work',
#  'spend time friend creative endeavor',
#  'my husband cuddle watch movie together',
#  'get talk mother phone last night speak need',
#  'the pork cook dinner last night turn well worried',
#  'able go bed early accomplish chore early anticipate',
#  'get unexpected call daughter nyc',
#  'four daycare kid give hug goodnight lay nap',
#  'happy come work find huge project cancel it big relief',
#  'hang friend',
#  'able walk dog around neighborhood it fun see flower people plant',
#  'wonderful meal girl',
#  'enjoy key lime yogurt morning breakfast',
#  'complete fitness goal morning set ago run full mile go work',
#  'walk home work see family park walk past join',
#  'happy return home russia morning',
#  'mow lawn yesterday make happy outside work',
#  'my old friend renee invite dinner',
#  'sit porch rock chair hold little girl son come spontaneously hug we',
#  'get accept college apply',
#  'get work particularly busy night make happy',
#  'happy wife work friend come visit',
#  'one thing make happy past hour spend quality time girlfriend',
#  'shopping make happy',
#  'go meet peruvian dance friend',
#  'snuggle dog give stinky breath kiss',
#  'find order book online like lot',
#  'go walk great talk random strange morning',
#  'one student tell pretty',
#  'receive birthday gift mail good friend mine',
#  'suffer fairly severe constipation last week experience relief morning',
#  'talk girlfriend recently tell love',
#  'finally chance talk thing really bother good friend',
#  'what make happy get lunch feel fulfil even burger fry',
#  'enough time make doro wat chicken store berbere sauce great',
#  'my neighbor come see completion project she give many positive compliment make happy',
#  'finally able order thing save past month',
#  'when able make old woman day grocery store',
#  'able find good batch mechanical turk hits',
#  'able go restaurant like',
#  'start watch black mirror good',
#  'after shovel neighbor driveway couple week back surprised order pizza dinner',
#  'get take patient floor hospital never',
#  'my daughter help clean kitchen without ask',
#  'watch hour training dvd zbrush',
#  'really tough workout morning manage complete run incredibly quickly',
#  'great cup coffee wake',
#  'my daughter smile first woke see face',
#  'look time realize half hour get work',
#  'finally enough money amazon payment account buy vertical smoker wanting',
#  'go grocery shopping purchase food cook wife',
#  'go see get wife',
#  'play cat lick face hour',
#  'wake wife give huge hug smile',
#  'get really excite periodically think upcoming weekend plan husband we go go weekend trip fill new food shopping watch new movie come ghost shell',
#  'in past hour family say trust responsible thing make happy',
#  'go walk early morning air clear crisp',
#  'when wife come home work day',
#  'talk preacher church fiance wanting get marry',
#  'finish project work hard work',
#  'my cat sit lap purr read book',
#  'make pizza home wife delicious',
#  'my partner wake give kiss left work',
#  'my diet seem work clothe fit bit looser',
#  'my year old son excellent job complete science project',
#  'when get home grocery store husband vacuumed floor take trash without ask',
#  'enjoy swimming beach near chennai',
#  'get call client confirm purchase order',
#  'happy run dungeon dragon campaign friend',
#  'piece rich moist chocolate cake ever',
#  'go last night friend make awesome drink chocolate syrup bailey irish cream',
#  'finish caloric log day calorie count app provide feedback state would weigh lb less next week',
#  'finally able take necessary step start learn japanese finally read first sentence feel really great inside',
#  'run two mile fast pace never achieve',
#  'play grandchild local park happy',
#  'giant chocolate cup cake',
#  'happy last evening paint garden',
#  'get raise work go evaluation yesterday morning hear back hour ago',
#  'this morning nephew sister law come visit along mother law',
#  'conversation girl meet online today',
#  'sell motorcycle get thousand dollar lot',
#  'hang close friend last night dinner drink',
#  'go hour run make feel great feel get well shape make feel good',
#  'check weight lose pound since start dieting month ago',
#  'sit outside backyard enjoy greenery sun shine face',
#  'go gym today run minute straight',
#  'my wife make chicken soup',
#  'go gym lunch break make happy',
#  'the beautiful weather outside make happy',
#  'package arrive door',
#  'receive bonus work',
#  'my ordered dress fit nicely',
#  'day work able binge watch tv show interruption',
#  'see baby ultrasound monitor',
#  'last night favorite hockey team play really well play bad game night',
#  'visit new park area enjoy nice walk',
#  'hit work goal early expect could actually quit want like hit',
#  'get see relative life another state',
#  'go eat favorite burger joint the burger delicious complete bliss',
#  'able run mile this ever do',
#  'happy go dinner last night friend see month',
#  'coffee make incredibly happy',
#  'my son good take play mall even though child',
#  'good day turk ever yesterday work hard help supplement income start work towards full garden hen house',
#  'able cell phone service plan significantly reduce cause great deal happiness yesterday',
#  'art contest today first prize free dvd',
#  'get go yoga relax hour',
#  'lottery scratch never win thing time',
#  'finally clean basement',
#  'get spend time play board game online girlfriend we currently mile away time spend together treasure valuable',
#  'when wake good night sleep sense satisfaction hit',
#  'get new laptop awesome',
#  'remind love eli manning much he honestly talente quarterback forget long see funny gif bring back many happy memory',
#  'in past hrs happy amazed boss tell entitle bonus relation new project make perfectly it big help wife happy feel fortunate you all life receive amount money company this first time',
#  'pleasant conversation girl like',
#  'strength training minute',
#  'djed online',
#  'my new boss appreciate work put',
#  'mow rake maintain lawn two old child happily help entire time',
#  'my basketball team game last second',
#  'happy get home work eat piece tiramisu wife make',
#  'my friend send funny picture',
#  'feel really happy work yesterday it relax worth place lunch break go outside sit padio cold beer vape pen watch youtube phone bask sun minute it great feel rejuvenated good mood feel happy',
#  'buy new pistol take range able shoot good',
#  'finally receive pep boys rebate form prepay visa card mail promptly use purchase item want amazon',
#  'after lunch take long walk around block near office lot sun many car pass',
#  'go jog',
#  'go gym able bench press lb',
#  'feel warmth sun walk outside dog',
#  'go friend drink bar',
#  'go run park work get well shape',
#  'give nice compliment work',
#  'it make happy start new instagram account upload picture show point view',
#  'my young daughter call chat awhile',
#  'meet friend lunch nice time socialize',
#  'pet cat curl nap it make happy close',
#  'wake exercise half hour happy start hurt less make bright beginning day',
#  'happy go physical therapy morning make feel well later day',
#  'see friend see good reconnect',
#  'my cat snuggle sleep',
#  'begin look home buy feel hope future',
#  'within past hour make happy take long nap stressful day study',
#  'run morning mile usually go mile push today see far could go',
#  'get spend evening husband enjoy company',
#  'hit goal walk mile day',
#  'work problem morning find solution problem happy word describe feeling',
#  'my son get cold drink kiss forehead feel well',
#  'make goal lose pound',
#  'go walk around block',
#  'my roommate make breakfast morning',
#  'my wife come home early work get spend extra time together',
#  'my husband kind sweet morning he sit talk we eat breakfast he wait see',
#  'my teen daughter make cup tea last night set next bed',
#  'go gym really enjoy awesome workout afterwards',
#  'my boyfriend go spring break visit family get back yesterday it nice wake next cuddle apart',
#  'carnival corp report beat estimate stock go way right bunch invest',
#  'get eat really delicious noodle mom make',
#  'buy new laptop',
#  'a friend mine verge cry she throw clutched clothe sigh relief hold tightly overwhelmed find comfort embrace',
#  'try book doctor appointment opening next day',
#  'talk phone mom morning',
#  'monday work service day',
#  'buy new pair headphone',
#  'it adapt stage musical film theater actor oh man seok debut director oh also lyricist polished script the story center around two guy crazy music one high school music teacher beom jin broken girlfriend eat sadly alone front mirror habit another young sae ki whose mother leave whose father die sudden accident leave orphan in rather dull world thing make two feel alive music offer happy life yoo jun sing i m choon gil alternate beom jin kim mu yeol ryan alternate sae ki',
#  'have dinner parent',
#  'buy jacket admire get great deal',
#  'my girlfriend come cuddle fall asleep',
#  'find good amount thing watch twitch enjoy quite lot',
#  'able make time play video game get around',
#  'receive free sushi coworker',
#  'in last hour husband decide go renew vowel make excited know still love year marriage',
#  'go watch soccer match stadium have fun cheer team',
#  'watch tv show stepdaughter',
#  'my friend treat nice lunch it seafood delicious pay anything',
#  'woke morning back pain go away completely',
#  'happy pick month old daughter first day day care yesterday see bright beaming smile',
#  'manage eat calorie goal day feel accomplish',
#  'get pay monday immediately use money pay long time credit card debt dentist finally free',
#  'my favorite hockey team win yesterday',
#  'get finally help mom get new doctor make appointment she ask help month know use internet search new doctor kp website',
#  'receive high score hard college exam paper',
#  'receive praise boss project complete',
#  'my spouse give big hug morning',
#  'watch movie spouse rub sore foot',
#  'enjoy cup coffee morning',
#  'watch bob burgers stream fox',
#  'get ten dollar bonus requester mechanical turk even remember hit',
#  'get new role project manager team work side job',
#  'decide skip gym night spend couple extra hour together girlfriend',
#  'at wildlife center volunteer injure beaver make full recovery able bring back home',
#  'talk phone girlfriend sick',
#  'my year old son try impress mother yesterday after dinner ask piece chocolate we mini hershey bar put one counter my son point chocolate bar finger move across letter say mom say turkeys it make laugh',
#  'my daughter climb bed snuggle pretend kitten',
#  'get relax spend time girlfriend worry anything else',
#  'go nice evening walk around neighborhood wife',
#  'get compliment look buff',
#  'when child get morning receive big hug kiss',
#  'able take minute relax prior starting work this make happy focused',
#  'pick new bedspread bed my bedspread hole need replace my husband happy length width spread',
#  'talk sister law phone yesterday evening it since last time talk really enjoy reconnecte',
#  'make money expect mturk',
#  'manage make next prize level hearthstone tournament mode previous high',
#  'do well videogame play',
#  'it son eighth birthday four day fun go baby picture old birthday photo',
#  'poker local bar buy round drink everyone cause feel good still happy event even morning',
#  'eat nice dinner delicious steak',
#  'get home work dog greet kiss want pet it make happy greet see happy',
#  'get do test nervous taking think pretty good',
#  'lunch mom one favorite spot',
#  'last night watch movie three friend home place it amazing day tired want spend time couple hour it great divine feeling work hard love one we enjoy moment hour',
#  'receive award excellence teach university it wonderful honor beautiful reception part',
#  'find wrong internet modem able fix',
#  'able see doctor receive medicine horrible cold',
#  'my son tell love beautiful face',
#  'finally repair problem car need help manage mostly',
#  'beautiful garden',
#  'get puppy saturday make happy cuddle',
#  'relaxed play mass effect computer',
#  'fall love girl iall never know she sit across starbucks unknowingly steal breath away yes iall never see hour love',
#  'help client learn stretch less pain',
#  'meet year old aunt lunch we catch family news',
#  'my employer offer switch part time full time work',
#  'my favorite tv show new episode watch',
#  'eat sriracha sour cream mash potato turn exceptionally well',
#  'go shoot pool friend game',
#  'get bonus mturk task',
#  'be able master song practice instrument',
#  'go bouldere gym good friend',
#  'manage pushup finally',
#  'this morning wife give hug tell important person world',
#  'manage vape good portion day yesterday try quit smoking every time make healthy choice job well do',
#  'a saw man help lady get something top shelf grocery store make happy thought nice something see everyday',
#  'daughter take nap day total hour allow hour quiet time',
#  'go date cute guy crush awhile',
#  'able complete everything schedule yesterday this make feel productive',
#  'my boyfriend tell smart beautiful left work feel love appreciate',
#  'when come home work two little grandson play front yard',
#  'go gym feel proud',
#  'manage make writing',
#  'yesterday donut work celebrate co worker birthday it nice surprise',
#  'some colleague finish project work',
#  'go short day hike wilderness park',
#  'go walk husband dog sun shine bird singe perfect spring day',
#  'gym hit new record different lift',
#  'finally convince girlfriend go movie we lot fun nice night',
#  'a friend take lunch today',
#  'laugh joke mother morning make happy',
#  'go swim florida vacation family',
#  'today son birthday excite open gift we',
#  'yesterday find buy persimmon tree home depot later plant tree front yard',
#  'play dog',
#  'make delicious cheeseburger afternoon it come great',
#  'listen happy song',
#  'give homeless person money',
#  'see sister today away month college',
#  'coworker make step help get hour work would give benefit high pay',
#  'play video game friend',
#  'make new friend online',
#  'my husband drive mall day weather perfect',
#  'go walk since nice day',
#  'run lap around neighborhood break previous record',
#  'manage make mechanical turk which make happy put money towards new office chair so way',
#  'watch wonderful movie see year my family thrill',
#  'play hour video game close friend',
#  'my son actually acknowledge woke morning instead grunt',
#  'finally receive package wait',
#  'long match online card game call hearthstone',
#  'spend time girlfriend last night',
#  'find fifty dollar floor break need buy lunch',
#  'give fiancee hug',
#  'watch entirety pharrell new hour music video happy aon mute hour chunk course several day still alive',
#  'basically get eye exam really help eye diabetes suffer vision problem end get prescription glass eye',
#  'that weather nice plant first vegetable season they grow weather nicely',
#  'go lunch father see since christmas',
#  'feel happy today guy interested ask hang later tonight',
#  'my daughter tell love hug bed time',
#  'send home early work',
#  'work gym get lot do',
#  'coworker bring donut breakfast',
#  'daughter blurt happy birthday happen wife birthday pass away april',
#  'give promotion work',
#  'the wife horny morning',
#  'get call job interview think qualified',
#  'happy listen album wildflowers vinyl',
#  'set new personal record squat one repetition pound',
#  'happiness mental emotional state well define positive pleasant emotion range contentment intense joy happy mental state may also reflect judgement person overall well a variety biological psychological economic religious philosophical approach striven define happiness identify source various research group include positive psychology happiness economic employ scientific method research question happiness might attain',
#  'go dunkin donuts girl write sexy cup name notice couple hour later make happy',
#  'walk step equal whole mile continue confidence breaker',
#  'able achieve something difficult work make co worker really happy',
#  'finish backlog paperwork work help',
#  'get chinese food dinner good',
#  'my friend sheryl come visit puppy',
#  'start small business',
#  'sit talk neighbor',
#  'talk girlfriend phone making weekend plan',
#  'make final table poker tournament',
#  'bench pressed pound last week pass one rep max',
#  'small young calf really sick think would make get last night stand really well happy proud little guy',
#  'get new vape pax mail today wait joy',
#  'it make happy get get fry lunch early',
#  'get period course suck let know everything good health wise',
#  'when buy new top favorite store',
#  'go outside see warm enough bike ride go three mile ride never ride far one session happy good excercise',
#  'my boss reward ticket pro hockey game play later week',
#  'help plan surprise party mom th birthday party come',
#  'when go bathroom',
#  'eat delicious dinner husband',
#  'dollar lottery scratch',
#  'able get establish well ground therapist',
#  'when free session school mean minute learn',
#  'great workout gym',
#  'my husband walk way nearby store pick beautiful card make feel well walk make even special',
#  'progress barbell bench press plateauing',
#  'finish make mega cake friend birthday come great',
#  'really happy finished midterm feel decently well happy',
#  'my husband give linger hug kiss leave work',
#  'get korean barbecue nearby food cart',
#  'make big dinner girlfriend last evening',
#  'come home okay new puppy happy see',
#  'my baby wake silly happy feel happy refresh fairly good night sleep enjoy silliness',
#  'get full night sleep that often happen month old house',
#  'today dog birthday fun play present',
#  'find interesting book library book know exist',
#  'go gym exercise elliptical lift weight work',
#  'finally complete long tiring task work',
#  'go local bar dinner old friend',
#  'increase max bench press morning heavy ever lift',
#  'take daughter lacrosse practice watch play',
#  'on way home purchase purple flower plant give significant arrive home work just see reaction make heart glow',
#  'see son try make grill cheese stove work well bread fall apart cheese burning come help make one ate together it make feel warm teach something even simple',
#  'happy get email discount triathlon want',
#  'cook new recipe want try it turn well',
#  'watch funny movie together husband we enjoy',
#  'my dog listen ask stay door go mailbox',
#  'get stay home work today take care stuff around house',
#  'pick daughter school she happy see',
#  'my husband come home morning get change ready work it nice see bit',
#  'get lot hour work yesterday good need money',
#  'eat pretty healthy today feel good',
#  'it make happy today learn make hard biology test',
#  'watch blackhawks game last night',
#  'my boyfriend get phone call say lose phone find',
#  'meet friend tea bible study session really fun engage',
#  'my husband get long really well lovely day yesterday we coffee watch news discuss thought simple thing make happy',
#  'there nest bird horse stall it beam watch mother bird build awhile when go stall today see could hear baby bird chirp it make happy see hatch',
#  'got eat dinner girlfriend sit bar watch game',
#  'try study individual frame animation pleased result',
#  'weigh morning lose weight lb exact',
#  'today make happy able enjoy time co worker outside work',
#  'happy take sunday afternoon nap',
#  'play videogame friend',
#  'complete pende job task today',
#  'a couple hour ago find get exam prepare long time',
#  'i m pilot fly today',
#  'we accept new apartment',
#  'enjoy fishing family early morning',
#  'realize aca people count support get keep health coverage',
#  'get really lucky draft possibly good deck ever hearthstone video game destroy first opponent simultaneously go bag lindt chocolate truffle realize really really happy the feeling euphoria last another minute lose three straight game back normal',
#  'my favorite tv show come',
#  'go sister see new baby smile',
#  'today receive new laptop amazon even arrive day early',
#  'complete online course put',
#  'happy online order arrive incredibly quickly',
#  'work garden nice warm weather the plant grow nicely air clean',
#  'cream chicken soup dinner it make feel lot well sick',
#  'my supervisor tell really good worker consider apply high job workplace',
#  'get take walk month old son husband the weather ver beautiful right cool sunny',
#  'talk phone good friend laugh lot',
#  'book flight colombia',
#  'give daughter present witness joy',
#  'receive large unexpected bonus mturk requester early today great every little bit help',
#  'run mile minute today make feel fast',
#  'go hike dog it beautiful sunny day park almost',
#  'give strange line coffee today',
#  'talk boyfriend',
#  'able help friend get money ssi',
#  'a girl crush show gym working morning',
#  'get money ssi',
#  'complete book reading really enjoy',
#  'get babysit grandchild love spend time',
#  'pick girlfriend airport since see two week',
#  'get meet old friend celebrate one birthday',
#  'receive new instrument classroom expect arrive',
#  'dance soca music mom sister',
#  'what make happy receive grade college get a b',
#  'suffer stomach bug husband make multiple trip walgreen grab gatorade medicine it make feel love',
#  'get sit plane several hour stretch',
#  'picture publish college newspaper',
#  'my ex girlfriend texte talk phone well',
#  'it th birthday',
#  'my girlfriend tell really happy happy meet',
#  'it spring break right work job much calm normal get spend quality time student relax',
#  'watch tv show',
#  'watch particularly compelling episode show enjoy netflix',
#  'get new dart electronic dart board basement get finally play',
#  'been try lose weight lately diet exercise morning woke weigh lose whole pound it make happy feel rewarding',
#  'my professor give extension assignment',
#  'tell school teach close week teacher still pay',
#  'got government job friend meet friend get to gather party m go to movie friend also movie',
#  'be very happy that someone who owe me money pay i back last night',
#  'go in n out work starve the double double taste good',
#  'happy read email requester give bonus',
#  'my kid twin boy wake today kiss hug',
#  'go beach girlfriend it nice see beautiful sunset go hold arm grateful life',
#  'eat chik fil',
#  'when walk classroom student run excitedly hug',
#  'the stray cat hang back porch last night finally find way home get worry',
#  'purchase new pant two size small usually buy',
#  'daughter commit college',
#  ...]

# %%
X_test=preprocess_data(df_test)

# %%
y_train=df_train['predicted_category']

# %%
label_encoder = LabelEncoder()
y_encode = label_encoder.fit_transform(y_train)
y=pd.DataFrame(y_encode)

# %% [markdown]
# ### Vectorizing

# %% [markdown]
# ### Bag of words

# %%
Xtrain_clean=pd.DataFrame({'data': X_train})
bow = CountVectorizer()          
bow.fit(Xtrain_clean['data'])               
X_bow = bow.transform(Xtrain_clean['data'])

# %% [markdown]
# ### TF IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(Xtrain_clean['data']) # vectorize feayures using tfidf

# %% [markdown]
# ### Prediction accuracy function

# %%
def pred(X,y,model):

    X_train, X_test, y_train, y_test = train_test_split( X,
                                                         y,
                                                         test_size=0.1,
                                                         random_state=1) 


    model.fit(X_train, y_train) 
    model = model.predict(X_test) 
    return accuracy_score(y_test, model)

# %% [markdown]
# ### KNeighborsClassifier

# %%
knn = KNeighborsClassifier() 
bow_accuracy=pred(X_bow,y,knn)

tfidf_accuracy=pred(X_tfidf,y,knn)
# Out:
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
bow_accuracy
# Out:
# 0.7410906679927067

# %%
tfidf_accuracy
# Out:
# 0.7062821150339798

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression() 
bow_accuracy=pred(X_bow,y,lr)
tfidf_accuracy=pred(X_tfidf,y,lr)
# Out:
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
bow_accuracy
# Out:
# 0.892756505884303

# %%
tfidf_accuracy
# Out:
# 0.8833084700812199

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier()
bow_accuracy=pred(X_bow,y,forest)
tfidf_accuracy=pred(X_tfidf,y,forest)
# Out:
# C:\Users\sn1x_\AppData\Local\Temp/ipykernel_17344/765708316.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# C:\Users\sn1x_\AppData\Local\Temp/ipykernel_17344/765708316.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)

# %%
bow_accuracy
# Out:
# 0.8486656721365822

# %%
tfidf_accuracy
# Out:
# 0.8519807724183657

# %% [markdown]
# ### Accuracy after balancing data

# %%
from imblearn.over_sampling import SMOTE

oversampling = SMOTE(sampling_strategy='auto')
X_new, y_new = oversampling.fit_resample(X_tfidf, y) 
y_new.value_counts()
# Out:
# 0    20880
# 1    20880
# 2    20880
# 3    20880
# 4    20880
# 5    20880
# 6    20880
# dtype: int64

# %%
lraccuracy=pred(X_new, y_new,lr)
accuracy
# Out:
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9432129173508483

# %%
knnaccuracy=pred(X_new, y_new, knn)
knnaccuracy
# Out:
# C:\Users\sn1x_\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.8293650793650794

# %%
rfaccuracy=pred(X_new, y_new, forest)
rfaccuracy
# Out:
# C:\Users\sn1x_\AppData\Local\Temp/ipykernel_17344/765708316.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# 0.9505336617405583
